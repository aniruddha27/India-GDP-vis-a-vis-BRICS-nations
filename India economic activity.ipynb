# %% [markdown]
# How does India's standard of living compare to that of other nations in the BRICS group based on their GDP values?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
#[name,index,color,linewidth,alpha]
index={0:[27,'Brazil','green',2,0.5],
       1:[200,'Russia','blue',2,0.5],
       2:[107,'India','orange',2,1],
       3:[38,'China','red',2,0.5],
       4:[261,'South Africa','black',2,0.5]
      }

# %% [markdown]
# ### world bank gdp data

# %%
file=r'C:\Users\Dell\Desktop\Machine Learning\Coursera\ds plot\project\country gdp.xls'
# importing excel file
xls=pd.ExcelFile(file)
gdp=xls.parse('Data')
gdp.head()
# Out:
#          Data Source World Development Indicators         Unnamed: 2  \
# 0  Last Updated Date          2018-11-14 00:00:00                NaN
# 1                NaN                          NaN                NaN
# 2       Country Name                 Country Code     Indicator Name
# 3              Aruba                          ABW  GDP (current US$)
# 4        Afghanistan                          AFG  GDP (current US$)
#
#        Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2  Indicator Code  1.960000e+03  1.961000e+03  1.962000e+03  1.963000e+03
# 3  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 4  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
#
#      Unnamed: 8    Unnamed: 9      ...        Unnamed: 52   Unnamed: 53  \
# ...

# %%
# renaming column names
gdp.rename(columns=gdp.iloc[2,:],inplace=True)
# removing top 2 rows of df
gdp=gdp.iloc[3:,:]
# resetting index values of df
gdp.index=np.arange(0,len(gdp))
# removing first 4 columns
gdp.drop(gdp.columns[:4],inplace=True,axis=1)
# changing the type of remaining columns to int
gdp.columns=gdp.columns.astype(int)
# removing first 30 columns
gdp.drop(gdp.columns[:30],inplace=True,axis=1)
#gdp.head()

# %%
gdp.iloc[:,:].head()
# Out:
#            1990          1991          1992          1993          1994  \
# 0           NaN           NaN           NaN           NaN  1.330168e+09
# 1           NaN           NaN           NaN           NaN           NaN
# 2  1.122876e+10  1.060378e+10  8.307811e+09  5.768720e+09  4.438321e+09
# 3  2.101625e+09  1.139167e+09  7.094526e+08  1.228071e+09  1.985674e+09
# 4  1.029048e+09  1.106929e+09  1.210014e+09  1.007026e+09  1.017549e+09
#
#            1995          1996          1997          1998          1999  \
# 0  1.320670e+09  1.379888e+09  1.531844e+09  1.665363e+09  1.722799e+09
# 1           NaN           NaN           NaN           NaN           NaN
# 2  5.538749e+09  7.526447e+09  7.648377e+09  6.506230e+09  6.152923e+09
# 3  2.424499e+09  3.314898e+09  2.359903e+09  2.707124e+09  3.414761e+09
# 4  1.178739e+09  1.223945e+09  1.180597e+09  1.211932e+09  1.239876e+09
#
#        ...               2008          2009          2010          2011  \
# ...

# %%
# check for null values corresponding to the BRICS nations
for i in range(len(index)):
    print(gdp.iloc[index[i][0],:].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
# converting to trillion $
gdp=gdp/10**12
gdp.head()
# Out:
#        1990      1991      1992      1993      1994      1995      1996  \
# 0       NaN       NaN       NaN       NaN  0.001330  0.001321  0.001380
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.011229  0.010604  0.008308  0.005769  0.004438  0.005539  0.007526
# 3  0.002102  0.001139  0.000709  0.001228  0.001986  0.002424  0.003315
# 4  0.001029  0.001107  0.001210  0.001007  0.001018  0.001179  0.001224
#
#        1997      1998      1999    ...         2008      2009      2010  \
# 0  0.001532  0.001665  0.001723    ...     0.002792  0.002499  0.002468
# 1       NaN       NaN       NaN    ...     0.010191  0.012487  0.015937
# 2  0.007648  0.006506  0.006153    ...     0.084178  0.075492  0.082526
# 3  0.002360  0.002707  0.003415    ...     0.012881  0.012044  0.011927
# 4  0.001181  0.001212  0.001240    ...     0.004007  0.003661  0.003356
#
#        2011      2012      2013      2014      2015      2016      2017
# ...

# %%
# dropping year 2018 as it contains null values
gdp.columns[-1]
# Out:
# 2017

# %% [markdown]
# ### world bank gdp per capita (ppp)

# %%
file=r'C:\Users\Dell\Desktop\Machine Learning\Coursera\ds plot\project\ppp per capita.xls'
xls=pd.ExcelFile(file)
ppc=xls.parse('Data')
#gdp.head()

# %%
# renaming column names
ppc.rename(columns=ppc.iloc[2,:],inplace=True)
# removing top 2 rows of df
ppc=ppc.iloc[3:,:]
# resetting index values of df
ppc.index=np.arange(0,len(ppc))
# removing first 4 columns
ppc.drop(ppc.columns[:4],inplace=True,axis=1)
# changing the type of remaining columns to int
ppc.columns=ppc.columns.astype(int)
# removing first 30 columns
ppc.drop(ppc.columns[:30],inplace=True,axis=1)
#gdp.head()

# %%
# checking for null values
for i in range(len(index)):
    print(ppc.iloc[index[i][0],:].isna().sum())
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
# since we have only single null values, they can be replaced with row mean  
for i in range(len(index)):
    ppc.iloc[index[i][0],:].fillna(ppc.iloc[index[i][0],:].mean(),inplace=True)

# %%
ppc.drop(ppc.columns[-1],inplace=True,axis=1)
ppc.columns[-1]
# Out:
# 2017

# %% [markdown]
# ### world bank gdp per capita

# %%
file=r'C:\Users\Dell\Desktop\Machine Learning\Coursera\ds plot\project\gdp per capita.xls'
xls=pd.ExcelFile(file)
gdp_per_capita=xls.parse('Data')
#gdp_per_capita.head()

# %%
# renaming column names
gdp_per_capita.rename(columns=gdp_per_capita.iloc[2,:],inplace=True)
# removing top 2 rows of df
gdp_per_capita=gdp_per_capita.iloc[3:,:]
# resetting index values of df
gdp_per_capita.index=np.arange(0,len(gdp_per_capita))
# removing first 4 columns
gdp_per_capita.drop(gdp_per_capita.columns[:4],inplace=True,axis=1)
# changing the type of remaining columns to int
gdp_per_capita.columns=gdp_per_capita.columns.astype(int)
# removing first 30 columns
gdp_per_capita.drop(gdp_per_capita.columns[:30],inplace=True,axis=1)
#gdp_per_capita.head()

# %%
gdp_per_capita.head()
# Out:
#            1990          1991          1992          1993          1994  \
# 0  12307.311738  13496.003385  14046.503997  14936.827039  16241.046325
# 1           NaN           NaN           NaN           NaN           NaN
# 2    922.550170    844.691134    640.622298    430.381595    320.657792
# 3    617.230436    336.586995    200.852220    367.279225    586.416340
# 4  18878.505969  19532.540150  20547.711790  16516.471027  16234.809010
#
#            1995          1996          1997          1998          1999  ...   \
# 0  16439.356361  16586.068436  17927.749635  19078.343191  19356.203389  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2    388.166766    512.620966    506.884952    419.639845    385.768853  ...
# 3    750.604449   1009.977275    717.380048    813.789397   1033.242532  ...
# 4  18461.064858  19017.174590  18353.059722  18894.521496  19261.710504  ...
#
# ...

# %%
for i in range(len(index)):
    print(gdp_per_capita.iloc[index[i][0],:].isna().sum())
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
# replacing null values with mean values
for i in range(len(index)):
    gdp_per_capita.iloc[index[i][0],:].fillna(gdp_per_capita.iloc[index[i][0],:].mean(),inplace=True)

# %%
gdp_per_capita.drop(gdp_per_capita.columns[-1],inplace=True,axis=1)
gdp_per_capita.columns[-1]
# Out:
# 2017

# %% [markdown]
# ### world bank gdp ppp

# %%
file=r'C:\Users\Dell\Desktop\Machine Learning\Coursera\ds plot\project\gdp ppp.xls'
xls=pd.ExcelFile(file)
ppp=xls.parse('Data')
ppp.head()
# Out:
#          Data Source World Development Indicators  \
# 0  Last Updated Date          2019-01-24 00:00:00
# 1                NaN                          NaN
# 2       Country Name                 Country Code
# 3              Aruba                          ABW
# 4        Afghanistan                          AFG
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 0                                 NaN                NaN         NaN
# 1                                 NaN                NaN         NaN
# 2                      Indicator Name     Indicator Code      1960.0
# 3  GNI, PPP (current international $)  NY.GNP.MKTP.PP.CD         NaN
# 4  GNI, PPP (current international $)  NY.GNP.MKTP.PP.CD         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9     ...       \
# 0         NaN         NaN         NaN         NaN         NaN     ...
# 1         NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
# renaming column names
ppp.rename(columns=ppp.iloc[2,:],inplace=True)
# removing top 2 rows of df
ppp=ppp.iloc[3:,:]
# resetting index values of df
ppp.index=np.arange(0,len(ppp))
# removing first 4 columns
ppp.drop(ppp.columns[:4],inplace=True,axis=1)
# changing the type of remaining columns to int
ppp.columns=ppp.columns.astype(int)
# removing first 30 columns
ppp.drop(ppp.columns[:30],inplace=True,axis=1)

# %%
for i in index:
    print(ppp.iloc[index[i][0],:].isna().sum())
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
# replacing null values with mean values
for i in range(len(index)):
    ppp.iloc[index[i][0],:].fillna(ppp.iloc[index[i][0],:].mean(),inplace=True)

# %%
ppp.drop(ppp.columns[-1],inplace=True,axis=1)

# %%
# converting to trillion
ppp=ppp/10**12
ppp.head()
# Out:
#        1990      1991      1992      1993      1994      1995      1996  \
# 0  0.001477  0.001649  0.001784  0.001947  0.002153  0.002264  0.002330
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.032558  0.038049  0.015429  0.016005  0.012923  0.029850  0.031030
# 3  0.008566  0.006115  0.005660  0.006577  0.007368  0.008654  0.009652
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        1997      1998      1999    ...         2008      2009      2010  \
# 0  0.002531  0.002640  0.002656    ...     0.003737  0.003394  0.003229
# 1       NaN       NaN       NaN    ...          NaN  0.041174  0.047883
# 2  0.038467  0.039371  0.037290    ...     0.114032  0.123823  0.131505
# 3  0.008743  0.009736  0.011047    ...     0.024374  0.025395  0.027766
# 4       NaN       NaN       NaN    ...          NaN       NaN       NaN
#
#        2011      2012      2013      2014      2015      2016      2017
# ...

# %% [markdown]
# ## plotting

# %%
fig,axes=plt.subplots(4,1,figsize=(8,12),dpi=100)

#for k in range(0,4):
for i in range(len(index)):
        
            # 1.gdp nominal
            #if k==0:
                axes[0].plot(gdp.iloc[index[i][0]],
                             label=index[i][1],
                             color=index[i][2],
                             linewidth=index[i][3],
                             alpha=index[i][4],)
                
                axes[0].set_ylabel('Trillion $')
                ##axes[k].text(2017+1,ylim/2,index[i][1],bbox={'boxstyle':'round','facecolor':index[i][2],'ec':index[i][2],'linewidth':'2','alpha':0.2})
                #axes[k].set_xticks(np.arange(1990,2018,3))
                axes[0].set_title('GDP nominal')
                #axes[0].fill_between(x=np.arange(1990,2018,3),y1=0,y2=gdp.loc[index[2][0],1990::3],facecolor='orange',alpha=0.10)
                #axes[0].get_xaxis().set_visible(False)
                axes[0].get_xaxis().set_ticks(np.arange(1990,2018,3))
                axes[0].set_xticks(np.arange(1990,2018,3))
                axes[0].set_xlim(1989.7,2017.5)
                
            # 2.gdp ppp
            #if k==1:
                axes[1].plot(ppp.iloc[index[i][0]],
                             label=index[i][1],
                             color=index[i][2],
                             linewidth=index[i][3],
                             alpha=index[i][4])
            
                #axes[1].annotate(index[i][1],xy=(2017+0.5,ppp.iloc[index[i][0],-1]),color=index[i][2])
                axes[1].set_ylabel('Trillion $')
                axes[1].set_xticks(np.arange(1990,2018,3))
                axes[1].set_yticks(np.arange(0,30,2))
                #axes[k][j].set_yticks(np.arange(0,3,0.2))
                axes[1].set_title('GDP PPP')
                #axes[1].axes.get_xaxis().set_ticks([])
                axes[1].set_xticks(np.arange(1990,2018,3))
                axes[1].set_xlim(1989.7,2017.5)
            
            
            # 3.gdp per capita
            #if k==2:
                axes[2].plot(gdp_per_capita.iloc[index[i][0]],
                             label=index[i][1],
                             color=index[i][2],
                             linewidth=index[i][3],
                             alpha=index[i][4])
            
                axes[2].annotate(index[i][1],xy=(2017+0.3,gdp_per_capita.iloc[index[i][0],-1]),color=index[i][2])
                axes[2].set_ylabel('$')
                axes[2].set_yticks(np.arange(0,18000,2000))
                axes[2].set_xticks(np.arange(1990,2018,3))
                axes[2].set_title('GDP per capita')
                axes[2].set_xlim(1989.7,2017.5)
                
            # 4.gdp per capita(ppp)
            #if k==3:
                axes[3].plot(ppc.iloc[index[i][0]],
                             label=index[i][1],
                             color=index[i][2],
                             linewidth=index[i][3],
                             alpha=index[i][4])
            
                axes[3].annotate(index[i][1],xy=(2017+0.3,ppc.iloc[index[i][0],-1]),color=index[i][2])
                axes[3].set_ylabel('$')
                #axes[3].set_xticklabels(np.arange(1990,2018,3))
                axes[3].set_xticks(np.arange(1990,2018,3))
                axes[3].set_yticks(np.arange(0,28000,3000))
                axes[3].set_title('GDP per capita (PPP)')
                axes[3].set_xlim(1989.7,2017.5)
            
            
# annotating plot 1
# Brazil
axes[0].annotate(index[0][1],xy=(2017+0.3,gdp.iloc[index[0][0],-1]-0.2),color=index[0][2])
# Russia
axes[0].annotate(index[1][1],xy=(2017+0.3,gdp.iloc[index[1][0],-1]-0.4),color=index[1][2])
# India
axes[0].annotate(index[2][1],xy=(2017+0.3,gdp.iloc[index[2][0],-1]+0.1),color=index[2][2])
# China
axes[0].annotate(index[3][1],xy=(2017+0.3,gdp.iloc[index[3][0],-1]),color=index[3][2])
# South Africa
axes[0].annotate(index[4][1],xy=(2017+0.3,gdp.iloc[index[4][0],-1]),color=index[4][2])

# annotating plot 2
# Brazil
axes[1].annotate(index[0][1],xy=(2017+0.3,ppp.iloc[index[0][0],-1]-0.6),color=index[0][2])
# Russia
axes[1].annotate(index[1][1],xy=(2017+0.3,ppp.iloc[index[1][0],-1]+0.2),color=index[1][2])
# India
axes[1].annotate(index[2][1],xy=(2017+0.3,ppp.iloc[index[2][0],-1]),color=index[2][2])
# China
axes[1].annotate(index[3][1],xy=(2017+0.3,ppp.iloc[index[3][0],-1]),color=index[3][2])
# South Africa
axes[1].annotate(index[4][1],xy=(2017+0.3,ppp.iloc[index[4][0],-1]),color=index[4][2])

# fill diff between top and India
axes[0].fill_between(x=np.arange(1990,2018),y1=gdp.loc[index[2][0],1990:2018],y2=gdp.loc[index[3][0],1990:2018],facecolor='orange',alpha=0.10)
axes[1].fill_between(x=np.arange(1990,2018),y1=ppp.loc[index[2][0],1990:2018],y2=ppp.loc[index[3][0],1990:2018],facecolor='orange',alpha=0.10)
axes[2].fill_between(x=np.arange(1990,2018),y1=gdp_per_capita.loc[index[2][0],1990:2018],y2=gdp_per_capita.loc[index[1][0],1990:2018],facecolor='orange',alpha=0.10)
axes[3].fill_between(x=np.arange(1990,2018),y1=ppc.loc[index[2][0],1990:2018],y2=ppc.loc[index[1][0],1990:2018],facecolor='orange',alpha=0.10)

# removing plot boundaries
for k in range(0,4):
    axes[k].spines['top'].set_visible(False)
    axes[k].spines['right'].set_visible(False)
    axes[k].spines['left'].set_visible(False)
    axes[k].spines['bottom'].set_visible(False)
    #axes[k].grid(axis='y',which='major',color='grey',alpha=0.2,linestyle='--',linewidth=1)

fig.subplots_adjust(hspace=150)
fig.subplots_adjust(wspace=10)
fig.tight_layout()
#axes[0].set_aspect('equal')
plt.show()

# %%
fig.savefig('Visualisation.jpg',bbox_inches='tight')
